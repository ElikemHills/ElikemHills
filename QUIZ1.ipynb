# %% [markdown]
# <a href="https://colab.research.google.com/github/ElikemHills/ElikemHills/blob/main/QUIZ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wgethttps://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv
# Out:
# /bin/bash: line 1: wgethttps://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv: No such file or directory

# %%
df=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin-1")

# %%
df
# Out:
#        Area Code     Area  Item Code          Item  Element Code  \
# 0              4  Algeria       2501    Population           511
# 1              4  Algeria       2501    Population          5301
# 2              4  Algeria       2901   Grand Total           664
# 3              4  Algeria       2901   Grand Total           674
# 4              4  Algeria       2901   Grand Total           684
# ...          ...      ...        ...           ...           ...
# 29912        123  Liberia       2562  Palm kernels          5611
# 29913        123  Liberia       2562  Palm kernels          5072
# 29914        123  Liberia       2562  Palm kernels          5911
# 29915        123  Liberia       2562  Palm kernels          5301
# 29916        123  Liberia       2562  Palm kernels          5131
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby('Area')['Area'].count()
# Out:
# Area
# Algeria                     1313
# Angola                      1424
# Benin                       1285
# Botswana                    1378
# Burkina Faso                1409
# Cabo Verde                  1260
# Cameroon                    1460
# Central African Republic    1344
# Chad                        1343
# Comoros                       45
# Congo                       1413
# Côte d'Ivoire               1467
# Djibouti                    1095
# Egypt                       1488
# Eswatini                    1284
# Ethiopia                    1447
# Ethiopia PDR                  39
# Gabon                       1245
# Gambia                      1168
# Ghana                       1354
# Guinea                      1410
# Guinea-Bissau               1128
# Kenya                       1560
# Lesotho                     1150
# Liberia                      408
# Name: Area, dtype: int64

# %%
df.groupby('Element')['Element'].fillna(value='mcf').count()
# Out:
# 29917

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29917 entries, 0 to 29916
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     29917 non-null  int64
#  1   Area          29917 non-null  object
#  2   Item Code     29917 non-null  int64
#  3   Item          29917 non-null  object
#  4   Element Code  29917 non-null  int64
#  5   Element       29917 non-null  object
#  6   Unit          29917 non-null  object
#  7   Y2014         29097 non-null  float64
#  8   Y2015         29070 non-null  float64
#  9   Y2016         29079 non-null  float64
#  10  Y2017         29135 non-null  float64
#  11  Y2018         29128 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 2.7+ MB

# %%
data.describe(include="all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   29917.000000  29917  29917.000000                    29917
# unique           NaN     25           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                      620
# mean       87.572918    NaN   2686.865929                      NaN
# std        68.155579    NaN    146.568791                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        37.000000    NaN   2561.000000                      NaN
# 50%        74.000000    NaN   2630.000000                      NaN
# 75%       114.000000    NaN   2775.000000                      NaN
# max       238.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit         Y2014  \
# count   29917.000000                     29917        29917  29097.000000
# ...

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df.duplicated().count()
# Out:
# 29917

# %%
df.describe(include="all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   29917.000000  29917  29917.000000                    29917
# unique           NaN     25           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                      620
# mean       87.572918    NaN   2686.865929                      NaN
# std        68.155579    NaN    146.568791                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        37.000000    NaN   2561.000000                      NaN
# 50%        74.000000    NaN   2630.000000                      NaN
# 75%       114.000000    NaN   2775.000000                      NaN
# max       238.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit         Y2014  \
# count   29917.000000                     29917        29917  29097.000000
# ...

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x=y[1][-1]

# %%
x
# Out:
# 8

# %%
df.isna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29917 entries, 0 to 29916
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     29917 non-null  bool
#  1   Area          29917 non-null  bool
#  2   Item Code     29917 non-null  bool
#  3   Item          29917 non-null  bool
#  4   Element Code  29917 non-null  bool
#  5   Element       29917 non-null  bool
#  6   Unit          29917 non-null  bool
#  7   Y2014         29917 non-null  bool
#  8   Y2015         29917 non-null  bool
#  9   Y2016         29917 non-null  bool
#  10  Y2017         29917 non-null  bool
#  11  Y2018         29917 non-null  bool
# dtypes: bool(12)
# memory usage: 350.7 KB
